# %% [markdown]
# # Author: Chandra Narayan

# %% [markdown]
# # Task 2: Image to Pencil Sketch with Python

# %% [markdown]
# Installing and Importing Libraries

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Reading Image

# %%
image = cv2.imread("F:/Chandan's Project/Image to Pencil Sketch with Python/dog.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,6))
plt.imshow(image)
plt.axis('off')
plt.title('Original Image')
plt.show()

# %% [markdown]
# Converting Image into Grayscale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,6))
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.title('Gray Image')
plt.show()

# %% [markdown]
# Invert Grayscale Image

# %%
inverted_image = 255 - gray_image
plt.figure(figsize=(8,6))
plt.imshow(inverted_image,cmap='gray')
plt.axis('off')
plt.title('Inverted image')
plt.show()

# %% [markdown]
# Blurring Inverted Image using Guassian Function in OpenCV

# %%
blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)
plt.figure(figsize=(8,6))
plt.imshow(blurred_image,cmap='gray')
plt.axis('off')
plt.title('Blurred Inverted image')
plt.show()

# %% [markdown]
# Final step: Inverting blurred image, then converting the image into pencil sketch

# %%
inverted_blurred = 255 - blurred_image
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
plt.figure(figsize=(8,6))
plt.imshow(pencil_sketch,cmap='gray')
plt.axis('off')
plt.title('Pencil Sketch')
plt.show()

# %% [markdown]
# Comparing the Original Image with the Sketch

# %%
image = cv2.imread("F:/Chandan's Project/Image to Pencil Sketch with Python/dog.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,6)).add_subplot(1, 2, 1)
plt.imshow(image)
plt.axis('off')
plt.title('Original Image')
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
plt.figure(figsize=(8,6)).add_subplot(1, 2, 2)
plt.imshow(pencil_sketch,cmap='gray')
plt.axis('off')
plt.title('Pencil Sketch')
plt.show()
